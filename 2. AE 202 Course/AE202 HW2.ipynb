# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np
import math as m

#Problem 1:

#Slopes of the line in K/m
a1 = -6.5*10**(-3) 
a2 = 3*10**(-3) 
a3 = -4.5*10**(-3) 
a4 = 4*10**(3) 

#heights of 1976 in m
h0 = 0
h1 = 11e3
h2 = 25e3
h3 = 47e3
h4 = 53e3
h5 = 79e3
h6 = 90e3
h7 = 105e3

#temperatures in K
t0 = 288.16 
t1 = 216.66 #temp for the straight portion (t1i = t1f)
t2 = 282.66 #temp for the straight portion (t2i = t2f)
t3 = 165.66 #temp for the straight portion (t3i = t3f)
t4 = 225.66 

#Defining variables
g0 = 9.81 #m/s
R = 287 #j/(kg*k)
P1 = 1.01325e5
rho1 = 1.225 #kg/m^3

#Isothermal (straight) Regions
#Sloped Regions

#def height(h):
#def altitude(a):
#def temp(t):
    
def Atmos1976(h):          #plug in h (atmosphere) to find temp
    if (h <= 11e3): #Sloped Regions
        T = a1*(h-h0)+t0
        P = P1*((T/t0)**(-g0/(a1*R)))
        Rho = rho1*((T/t0)**(-g0/(a1*R)))
        return T, P, Rho;

    elif (h > 11e3 and h < 25e3): #Isothermal (straight) Regions
        T = 216.66
        P = P1*((t1/t0)**((-g0/(a1*R)))) * (m.e**((-g0/(R*T))*(h-h1)))
        return T, P;
    
    elif (h >= 25e3 and h <= 47e3): #Sloped Regions
        T = a2*(h-h1)+t1
        P = P1*((t1/t0)**((-g0/(a1*R)))) * (m.e**((-g0/(R*T))*(h-h1)))
        return T, P;
    
    elif (h > 47e3 and h < 53e3): #Isothermal (straight) Regions 
        T = 282.66
        
    elif (h >= 53e3 and h <= 79e3): #Sloped Regions
        T = a3*(h-h2)+t2
        P = P1*((t1/t0)**((-g0/(a1*R)))) * (m.e**((-g0/(R*T))*(h-h1)))
        return T, P;
    
    elif (h > 79e3 and h < 90e3): #Isothermal (straight) Regions
        T = 165.66
        
    elif (h >= 90e3 and h <= 105e3): #Sloped Regions
        T = a4*(h-h3)+t3
        P = P1*((t1/t0)**((-g0/(a1*R)))) * (m.e**((-g0/(R*T))*(h-h1)))
        return T, P;

print(Atmos1976(10e3))



    

2+2
